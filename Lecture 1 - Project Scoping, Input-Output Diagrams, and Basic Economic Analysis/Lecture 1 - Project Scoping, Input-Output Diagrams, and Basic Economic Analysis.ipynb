# %% [markdown]
# <h1> Lecture 1: Project Scoping, Input-Output Diagrams, and Basic Economic Analysis </h1>

# %% [markdown]
# <h2> Objectives </h2>
# <br/>
#
# By the end of this lecture you should be able to:
#
# <h3>Define</h3> components of a design basis memorandum
#
# <h3>Apply</h3> basic measures of economic merit to perform initial estimates of project feasibility
#
# <h3>Create</h3> input-output diagrams

# %% [markdown]
# <h2> Phases in the Construction of a Plant </h2>
#
# <ol>
#     <li><strong> Basic Engineering</strong> </li>
#     <br>
#     <li> Detailed Engineering </li>
#     <br>
#     <li> Construction </li>
#     <br>
#     <li> Commissioning (start-up) </li>
#     </ol>
#
# <em> In this course, we will only focus on <strong>basic engineering </strong>.</em>
#
# <h3> What do we produce as engineers? </h3>
#
# <strong>Basic Design Package </strong>: This document is provided to clients by engineers and may consist of the following:
#
# <p style="text-align:center;">
# <img src="Lecture1-Images/Diagram.PNG" width=500>
# </p>
#
# <blockquote>Startail Management and Consulting Services have a thorough basic engineering design package that you can find in <a href="http://www.startail.it/thw_inustrial/bedp/">this link</a></blockquote>
# <br>
# <strong> Design Basis Memorandum (DBM)</strong>: This document contains key information and data that is relevant to the project deliverables.
#
# A design basis memorandum is typically 10-20 pages and consists of the following information:<br>
#     <ol>
#         <li> Contractual issues </li><br>
#         <blockquote>
#     <ul>
#             <li> Project scope </li>
#             <ul>
#                 <li> High level description of product to be made </li>
#                 <li> Feeds used in the process </li>
#                 <li> Technology description </li>
#             </ul>
#             <li> Plant capacity and location </li>
#             <li> Product specification </li>
#             <ul>
#                 <li> Composition purity</li>
#                 <li> Temperature </li>
#                 <li> Pressure </li>
#             </ul>
#             <li> Operating philosophy </li>
#             <li> Deliverables and schedule </li>
#             <ul>
#                 <li> Gantt chart </li>
#             </ul>
#             </ul> </blockquote>
#     <li> Plant site-specific issues </li><br>
#     <blockquote>
#         <ul>
#             <li> Feed specifications </li>
#             <ul>
#                 <li> Temperature </li>
#                 <li> Pressure </li>
#                 <li> Composition </li>
#             </ul>
#             <li> Utilities </li>
#             <li> Emission requirements </li>
#             <ul>
#                 <li> What the site can emit according to local law </li>
#             </ul>
#             <li> Site environmental conditions </li>
#             <ul>
#                 <li> Atmospheric pressure </li>
#                 <li> Wind </li>
#                 <li> Maximum and minimum temperatures </li>
#                 <li> Rainfall </li>
#             </ul>
#             <li> Environmental and safety issues </li>
#             <li> Control and electrical requirements </li>
#         </ul>
#     </blockquote>
#         <li> Design-specific issues </li>
#     <blockquote>
#     <ul>
#         <li> Equipment, instrument, and line numbering </li>
#         <li> Units </li>
#         <li> Standards </li>
#         <ul>
#             <li> Certain technical equipment have certain standards (pressure vessels, heat exchangers, electrical work) </li>
#         </ul>
#     </ul>
#     </blockquote>
#     </ol>

# %% [markdown]
# <h2> Process Design Scope </h2>
#
# <ul>
#     <li><strong> Inside Battery Limits</strong>: equipment and components that are associated with the main process feed stream.[1]</li>
#     <br>
#     <li><strong> Outside Battery Limits</strong>: equipment, components, utilities, and other facilities (not included in inside battery limits) that are associated with multiple units.[1]</li>
# </ul>
# <br>
# <div style="background-color:rgba(75, 171, 215, 0.15)">
# <h3> Example: Production of Vinyl Chloride </h3>
#
# We want to build a plant that produces 360,000 tonnes per year of a vinyl chloride monomer to be used in the production of polyvinyl chloride (PVC).
#
# $$C_{2}H_{4} + Cl_{2} → C_{2}H_{4}Cl_{2} (1)$$
# <br>
# $$C_{2}H_{4}Cl_{2} → C_{2}H_{3}Cl + HCl (2) $$
#
# For contractual issues:
#
# <blockquote>
#     <ul>
#         <li> High level description of vinyl chloride</li>
#         <li> Ethane and chlorine feed to be used </li>
#         <li> Reactor type being used </li>
#         <li> Plant capacity of 360,000 tonnes/yr of vinyl chloride, located in Houston, Texas </li>
#         <li> Operating composition purity, temperature, and pressure </li>
#         <li> Operating philosphy </li>
#         <li> Gantt chart showing project time line </li>
#     </ul>
#     </blockquote>
#
# For site-specific issues:
#
# <blockquote>
#     <ul>
#         <li> Temperature, pressure, and composition of feed (inside battery limits) </li>
#         <li> Cooling water used at $25 ^{\circ}C$ and 2 atm and steam at $20^{\circ}C$ and 3 atm (outside battery limits) </li>
#         <li> Emission predictions and requirements </li>
#         <li> Atmospheric pressure, little wind and rainfall, maximum and minimum temperatures at location </li>
#         <li> Environmental and safety issues at locations </li>
#         <li> Control and electrical requirements of plant </li>
#     </ul>
#     </blockquote>
#
# For design-specific issues:
#    <blockquote>
#     <ul>
#         <li> Equipment, instrument, and line numbering </li>
#         <li> Units </li>
#         <li> Standards </li>
#         <ul>
#             <li> Certain technical equipment have certain standards (pressure vessels, heat exchangers, electrical work) </li>
#         </ul>
#     </ul>
#     </blockquote>
#
#
# </div>

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <h3>Exercise: Battery Limits</h3>
# <br>
#
# Consider a process where benzene is fed into a process for oxidization and purification in a plant. The process also consists of using 2 utility streams (cold water and steam) in the heat exchanger portion, as well as a waste water treatment operation. Classify the oxidation, purification, waste water treatment, and utility usage as either inside battery limit or outside battery limit.
#
#
#
#
# </div>
#
#
# <details>
#   <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <strong>Solution</strong>
# <br/>
#
# <ul>
#     <li> Oxidation: inside battery limit - this will be done of the benzene <strong>feed (primary)</strong> stream </li>
#     <br>
#     <li> Purification: inside battery limit - this will be done of the benzene <strong>feed (primary)</strong> stream </li>
#     <br>
#     <li> Waste Water Treatment: outside battery limit - the waste water treatment is a <strong>secondary</strong> process</li>
#     <br>
#     <li> Utitilities: outside battery limit - utilities are <strong>secondary</strong> process elements </li>
#     </ul>
#
#
#
# </div>
# </details>

# %% [markdown]
# <h3> Scholarly Societies Relevant to CHBE Students </h3>
#
# <ul>
#     <li><a href="https://www.cheminst.ca/about/about-csche/">Canadian Society of Chemical Engineeering (CSChE)</a> </li>
#     <br>
#     <li><a href="https://www.icheme.org/">Institution of Chemical Engineers (IChemE)</a> - based in the UK and Australia </li>
#     <br>
#     <li><a href="https://www.soci.org/">Society of Chemical Industry</a> - based in the UK and industry focused</li>
#     <br>
#     <li><a href="https://www.aiche.org/">American Institute of Chemical Engineers (AIChE)</a></li>
#     </ul>
#
# Joining AIChE is highly recommended:
# <ul>
#     <li> Registration is free for undergraduates </li>
#     <li> Scholarship opportunities, e-library access, professional networking, career services and webinars, online access to ChemEng Process magazine</li>
#     </ul>
#
#
#
# Joining CSChE is recommended:
# <ul>
#     <li> Registration is free for undergraduates in their first year of a chemical engineering program (Y2 at UBC) and  35 CAD a year after that </li>
#     <li> e-library access and professional networking events </li>
# </ul>
#
# IChemE might be relevant to you depending on where you are in the future:
# <ul>
#     <li> Registration is 25 GBP for undergraduates for the entire program of study </li>
#     <li> e-library access </li>
#     <li> Professional networking, career services, and webinars </li>
#     <li> Online acess to Chemical Engineering Magazine </li>

# %% [markdown]
# <h2> Input-Output Diagrams </h2>
#
# These diagrams are considered to be the simplest process flow sheet.
#
# <p style="text-align:center;">
# <img src="Lecture1-Images/InputOutput.PNG" width=500>
# </p>
#
# The entire process here will be represented by 1 block only.
#
# <div style="background-color:rgba(75, 171, 215, 0.15)">
# <h3> Example: Ammonia Production Block Diagram </h3>
# <br>
#
# Consider an ammonia production process where 3 streams of raw materials enter the process:
#     <ul>
#         <li> 700 tons/day of methane </li>
#         <li> 1590 tons/day of water </li>
#         <li> 1650 tons/day of nitrogen </li>
#     </ul>
#
# The process produces 2 product streams:
#     <ul>
#         <li> 2000 tons/day of ammonia </li>
#         <li> 1940 tons/day of carbon dioxide </li>
#     </ul>
#
# We can put together the following input-output diagram for this process:
# <p style="text-align:center;">
# <img src="Lecture1-Images/AmmoniaProcess.PNG" width=500>
# </p>
# <br>
#
# </div>

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <h3>Exercise: Benzene Production</h3>
# <br>
#
# Consider a process where toluene is fed into a process at 1000 kg/hr and hydrogen is fed at 82 kg/hr. The following reaction takes place in the process:
#
# $$C_{7}H_{8} + H_{2} ➡ C_{6}H_{6} + CH_{4} $$
#
# The reaction achieves 75% conversion and the products of the process are separated into 2 streams. The first product stream is benzene, exiting at 821 kg/hr. The second product stream is a mixed gas stream exiting at 261 kg/hr. Draw an input-output diagram for this process.
#
#
#
# </div>
#
#
# <details>
#   <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <strong>Solution</strong>
# <br/>
#
# <p style="text-align:center;">
# <img src="Lecture1-Images/BenzeneProduction.PNG" width=500>
# </p>
# <br>
#
#
#
# </div>
# </details>

# %% [markdown]
# <h2> Process Economics </h2>
#
# Finding chemical pricing data can be very challenging. Companies typically want to keep this information secret (gives competitors an edge and easier for clients to 'disqualify' companies).
#
#
# Four basic figures of merit:
#
# <ol>
#     <li> <strong>Gross Economic Potential (GEP) </strong>: generally in dollars/yr</li>
#     GEP = value of Products - Value of Feeds <br>
#     <br>
#     <li> <strong>Net Economic Potential (NEP) </strong>: generally in dollars/yr</li>
#     NEP = GEP - Production Costs (utilities, labour, maintainance) <br>
#     <br>
#     <li> <strong> Capital Costs (CC) </strong>: generally in dollars</li>
#     CC = Cost of plant design and construction <br>
#     <br>
#     <li> <strong> Return on Investment (ROI) </strong>: generally in %yr </li>
#     ROI = NEP/CC*100%  <br>
# </ol>
#
#
# <h3> Finding Chemical Pricing Data </h3>
#
#
# <ol>
#     <li> Go to <a href="https://tamu.libguides.com/chemicalengineering/cpd"> Texas A&M Chemical Pricing Database </a> </li>
#     <li> Search the chemical by name (i.e. Ethylene) of CAS number (Chemical Abstracts Services; can be found on Wikipedia) </li>
#     <li> Find a citation from 'ICIS Chemical Business' and note the edition and page number (i.e. 2018, April 6; 19)</li>
#         <li> Go to <a href="http://search.library.ubc.ca/">UBC Library</a> and type in "ICIS Chemical Business" into the search bar and search</li>
#     <li> Click on the source by Factiva, Business Source Ultimate </li>
#     <li> Click on 'Browse Journal' and then on the 'Search within this publication' link </li>
#     <li> Find the citation you found from the Texas A&M Database citation using the dates </li>
#     <li> Once you find your article, click 'UBC eLink'. This should take you to a new page where you can access the full text </li>
#     <li> Search through the article for the chemical of interest's price </li>
#
# </ol>
#
# This process is tedious and often takes some time.

# %% [markdown]
# <div style="background-color:rgba(75, 171, 215, 0.15)">
# <h3> Example: Production of Vinyl Chloride </h3>
#
# Our client wants to produce 360,000 tonnes/yr (800 million lbs/yr) of vinyl chloride monomer. We decide to use the following pathway for this process:
#
# $$C_{2}H_{4} + Cl_{2} → C_{2}H_{4}Cl_{2} (1)$$
# <br>
# $$C_{2}H_{4}Cl_{2} → C_{2}H_{3}Cl + HCl (2) $$
#
#
# We gather the following information on the process:
#
# <table>
#     <thead>
#         <tr><th style="text-align:center">Name</th><th style="text-align:center">Formula</th><th style="text-align:center">Molecular Weight (g/mol)</th><th style="text-align:center">Price (USD/tonne)</th></tr>
#     </thead>
#     <tbody>
#         <tr><td style="text-align:center">Ethene</td><td style="text-align:center">$C_{2}H_{4}$</td><td style="text-align:center">28.05</td><td style="text-align:center">733</td></tr>
#         <tr><td style="text-align:center">Chlorine</td><td style="text-align:center">$Cl_{2}$</td><td style="text-align:center">70.91</td><td style="text-align:center">240</td></tr>
#         <tr><td style="text-align:center">Dichloroethane</td><td style="text-align:center">$C_{2}H_{4}Cl_{2}$</td><td style="text-align:center">98.96</td><td style="text-align:center">300</td></tr>
#         <tr><td style="text-align:center">Hydrogen Chloride</td><td style="text-align:center">$HCl$</td><td style="text-align:center">36.46</td><td style="text-align:center">140</td></tr>
#         <tr><td style="text-align:center">Vinyl Chloride</td><td style="text-align:center">$C_{2}H_{3}Cl$</td><td style="text-align:center">62.50</td><td style="text-align:center">750</td></tr>
#     </tbody>
#     </table>
#
#
# <h3> Input-Output Diagram </h3>
#
# We know that one of the product streams will be 360,000 tonnes/yr of vinyl chloride. Hydrogen chloride is produced in a 1:1 molar ratio with vinyl chloride:
#
# $VC = 360,000 tonnes/yr*\frac{tonne-mol}{62.50 tonnes} = 5,760\frac{tonne-mol}{yr}$
#
# $HCl = 5,760\frac{tonne-mol}{yr}*36.46\frac{tonnes}{tonne-mol}=210,000\frac{tonnes}{yr}$
#
# Similarly for ethane and chlorine, we get:
#
# $C_{2}H_{4} = 5,760\frac{tonne-mol}{yr}*28.05\frac{tonnes}{tonne-mol}=162,000\frac{tonnes}{yr}$
#
# $Cl_{2} = 5,760\frac{tonne-mol}{yr}*70.91\frac{tonnes}{tonne-mol}=408,000\frac{tonnes}{yr}$
# <br>
#
# From this and the information in the table, we get the following input-output diagram:
#
# <p style="text-align:center;">
# <img src="Lecture1-Images/VCProduction.PNG" width=600>
# </p>
# <br>
#
# <h3> Process Economics </h3>
#
# 1 - Gross Economic Potential (GEP) in USD/yr
#
# <p style="text-align:center;"><strong> GEP = Value of Products - Value of Feeds </strong></p>
#
# $$GEP=140\frac{USD}{tonne}*210,000\frac{tonnes}{yr} + 750\frac{USD}{tonne}*360,000\frac{tonnes}{yr}-733\frac{USD}{tonne}*162,000\frac{tonnes}{yr}-240\frac{USD}{tonne}*408,000\frac{tonnes}{yr}$$
#
# $$GEP=83,000,000\frac{USD}{tonne}$$
#
#
# 2 - Net Economic Potential (NEP) in USD/yr
#
# <p style="text-align:center;"><strong> NEP = GEP - production costs</strong> </p>
#
# Assume our production costs are $200\frac{USD}{tonne}$ of VC produced.
#
# $$NEP=83,000,000\frac{USD}{tonne}-200\frac{USD}{tonne}*360,000\frac{tonne}{yr}$$
#
# $$NEP=11,000,000\frac{USD}{yr}$$
#
#
# 3 - Capital Costs (CC) in USD
#
# <p style="text-align:center;"><strong> Total cost of plant design and construction</strong> </p>
#
# Assume our VC production plant costs $50,000,000 USD$ to build. This value usually depends on the size of the plant, location, and other factors.
#
#
# 4 - Return on Investment (ROI) in %/yr
#
# <p style="text-align:center;"><strong> ROI = NEP/CC*100% </strong></p>
#
# $$ROI=11,000,000\frac{USD}{yr}*\frac{1}{50,000,000 USD}*100%$$
#
# $$ROI=22%/yr$$
#
# ROI is generally written in %, but %/yr is usually assumed. A higher ROI is desired.
#
#
# </div>

# %% [markdown]
# <h2> References </h2>
#
# [1] CII - CII Glossary. [Online]. Available: https://www.construction-institute.org/resources/knowledgebase/about-the-knowledge-base/glossary/cii-glossary. [Accessed: 29-May-2020].

# %% [markdown]
# # Lecture 16 - Process Economics – plant capital cost estimation

# %% [markdown]
# ## Objectives
#
# ### Understand
#
# The elements that contribute to the capital cost for a plant
#
# ### Estimate
#
# The purchased equipment price based on baseline data using the effect of capacity and time
#
# The total capital investment (TCI) based on the lang factor

# %% [markdown]
# ## Total Capital Investment (TCI)
#
# The amount of money (aka. capital) needed for a project to proceed. This is further divided into 2 types of capital:
# * Fixed Capital Investment (FCI)
# * Working Capital (WC)
#
# <font color="red"> $$TCI = FCI + WC$$ </font>
#
# TCI is the total amount of funds needed to build and start a chemical plant, including the testing and troubleshooting stages before the actual production. It does not include operating expenses or maintenance during the production process.

# %% [markdown]
# ## Fixed Capital Investment (FCI)
#
# Fixed capital investment is the total price to purchase equipment, get it installed and tested.
#
# FCI is made up of direct costs and indirect costs. These are described below and common direct and indirect cost catgories are listed in the table below.
#
# * Direct costs: related to tangible things or products such as process equipment.
# * Indirect costs:  related to intangible items, these won't stay at the end of building the plant, for example supervision and project management expenses.
#
# <p style="text-align:center;"><strong>Table 1: Examples of Direct and Indirect Costs that Contribute to FCI</strong></p>
#
# |Directs costs| Indirect costs |
# | :-- | :-- |
# | 1. purchased equipment (PE) cost     | 1. Engineering and supervision |
# | 2. PE installation     | 2.Construction expenses |
# | 3. Instrumentation and controls | 3. Contractor's fee|
# | 4. Piping | 4. Contingency |
# | 5. Electrical equipment and materials |   |
# | 6. Buildings |  |
# | 7. Yard improvements |  |
# | 8. Service facilities |  |
# | 9. Land |  |

# %% [markdown]
# ## Working Capital (WC)
#
# The Working Capital is the initial money required to start the plant. You can think of this like a float (initial money in a cash box) when selling something like samosas or baked goods in CHBE. It is money needed for supplies or people that is not recovered until after the plant closes. Since this is generally a long-time in the future, it is considered a capital investment rather than manufacturing costs.
#
# WC includes capital invested in:
# 1. Raw materials and supplies in stock
# 2. Finished product in stock and working capital
# 3. Cash for monthly operating expenses such as wages, utility bills etc
# 4. Accounts receivable
# 5. Accounts payable
# 6. Taxes payable
#
# Typically the WC is <font color="red"> 10 -20% of the TCI </font> for most chemical plants.

# %% [markdown]
# ## Purchased Equipment (PE) Cost
#
# PE is the purchase price of equipment from a vendor (someone selling the equipment). It is one of the major factors in the direct costs.
#
# It only includes the cost to build the equipment, but does not include the cost associated with transportation of that equipment to the site, installation, etc.
#
# Many times we may estimate PE costs based on costs of PE from previous projects. We will usually use factors to adjust the cost for <strong>capacity</strong> or changes in prices over <strong>time</strong>.

# %% [markdown]
# ### Effect of Capacity
#
# There are a variety of ways to adjust PE pricing to account for different equipment capacity (bigger or smaller equipment). The most common, simple relationship, and the one we'll use in this class, is shown below:
#
# <font color="red"> $$\frac{C_{a}}{C_{b}}=\Big(\frac{A_{a}}{A_{b}}\Big)^n$$ </font>
#
# Where
# > $C_{a}$ - desired equipment cost
# >
# > $C_{b}$ - base cost for known equipment
# >
# > $A_{a}$ - desired capacity
# >
# > $A_{b}$ - base capacity
# >
# > $n$ - cost exponent (given for each type of equipment)
#
# We can rearrange this equation and plot it in a linear form as well (many times you may see log-based plots comparing equipment capacity and cost):
#
# <font color="red"> $$ln(C_{a})=ln(K)+n ln(A_{a})$$ </font>
# where
# > $K=\frac{C_{b}}{A_{b}^n}$
#
# If you are curious, we show how this equation is derived below:
#
# Since $C_{b}$ and $A_{b}$ are known information for another piece of equipment, we can treat them as constants and take use$K$ to represent $\frac{C_{b}}{A_{b}^n}$, and take the ln of both sides of the equation.
#
# \begin{align*}
# \frac{C_{a}}{C_{b}}&=\Big(\frac{A_{a}}{A_{b}}\Big)^n\\
# C_{a} & = \frac{C_{b}}{A_{b}^n}×A_{a}^n\\
# C_{a} & = K × A_{a}^n \\
# ln(C_{a}) &= ln(K) + n ln(A_{a}) \\
# \end{align*}

# %% [markdown]
# Jonathan TODO - need to update this and sources for this information - Perry's and others.
#
# <p style="text-align:center;"><strong>Table 2: Examples of Cost Exponents for Process Equipment$^{[2]}$</strong></p>
#
# |Equipment Type |Range of Correlation| Capacity Units| Cost Exponent (n)|
# | :-- | :--: | :--: | :--: |
# |Reciprocating compressor with motor drive| 1 -1500| $kW$ |0.85|
# |Heat exchanger shell and tube carbon steel| 1.9 – 1860| $m^2$ | 0.60|
# |Vertical tank carbon steel| 0.5-74| $m^3$ |0.30|
# |Pump centrifugal carbon steel| 1-70| $hp$ |0.67|
# |Jacketed kettle glass lined| 0.2-3.8| $m^3$ |0.47|
#
#
# You may notice many of these have a cost exponent Six-tenth rule: for a lot of process units, we can take n=0.60

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Using capacity correlation to estimate purchased equipment cost</strong>
#
# If a 0.8 $m^3$ glass lined jacketed kettle costs 35,000 dollars, how much does a piece of similar equipment with a capacity of 3.0 $m^3$? Compare the results using the given cost exponent and the six-tenth rule.
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# **using n=0.48 given by the cost exponent**
#
# \begin{align*}
# \frac{C_{a}}{C_{b}}&=\Big(\frac{A_{a}}{A_{b}}\Big)^n\\
# C_{a} & = C_{b}×\Big(\frac{A_{a}}{A_{b}}\Big)^n\\
# C_{a} & = 35000 × \Big(\frac{3.0}{0.8}\Big)^{0.48}\\
# C_{a} & ≈66000 \\
# \end{align*}
#
# **Using n=0.60 given by the six-tenth rule**
#
# \begin{align*}
# \frac{C_{a}}{C_{b}}&=\Big(\frac{A_{a}}{A_{b}}\Big)^n\\
# C_{a} & = C_{b}×\Big(\frac{A_{a}}{A_{b}}\Big)^n\\
# C_{a} & = 35000 × \Big(\frac{3.0}{0.8}\Big)^{0.60}\\
# C_{a} & ≈77400 \\
# \end{align*}
#
# Shows the difference these factors can make, need to be sure these are as accurate as possible.
# </p>
# </div>
# </details>

# %% [markdown]
# ### Effect of Time
#
# As you may know, the value of money changes with time due to factors such as inflation. Cost indexes tell us what a common item costs at different points in time.
#
# <font color="red"> $$C_{2}=C_{1}\Big(\frac{I_{2}}{I_{1}}\Big)$$</font>
#
# where
# > $C_{1}$ - known cost of equipment/plant at a past time
# >
# > $C_{2}$ - cost of equipment/plant at the time of interest
# >
# > $I_{1}$ - the cost index at known time
# >
# > $I_{2}$ - the cost index at the time of interest
#
# <p style="text-align:center;"><strong>Table 3: Cost index for 1996-2016 $^{[1]}$</strong></p>
#
# |Year|Marshall and Swift Equipment cost index |Chemical Engineering Plant Cost Index|
# | :-- | :--: | :--: |
# | 1996 | 1036 | 382 |
# | 2000 | 1070 | 394 |
# | 2004 | 1133 | 444 |
# | 2008 | 1393 | 575 |
# | 2012 | 1537 | 585 |
# | 2016 | 1582 | 542 |
#
# <strong>Marshall and Swift Equipment cost index</strong> and <strong>Chemical Engineering Plant Cost Index $^{[1]}$</strong> are two common types of cost indexes that we will use for this course.
#
# Note the Marshall and Swift is used for equipment, whereas the plant cost index is for an overall plant cost including installation, piping, etc.
#
# The Chemical Engineering Plant Cost Index is calcuated based on the effect of time on costs of common components across a range of chemical plants:
#
# <p style="text-align:center;"><strong>Table 4: Composition of the Chemical Engineering Plant Cost Index $^{[1]}$</strong></p>
#
# |Index Component | Weighting of component (%)|
# | :-- | :--: |
# |Equipment machinery and supports (shown in detail below)| 61|
# |Erection and installation labour| 22|
# |Buildings, materials and labour| 7 |
# |Engineering and supervision |10|
# |Index overall total| 100 |
#
#
#
# <p style="text-align:center;"><strong>Table 5: Composition of Equipment Maschinery and Supports Cost for Chemical Engineering Plant Cost Index$^{[1]}$</strong></p>
#
# |Index Component for EquipmentMachinery and supports|  Weighting of component (%) |
# | :-- | :--: |
# |Fabricated Equipment| 37|
# |Process Machinery| 14|
# |Pipe, valves and fittings| 20|
# |Process instruments and controls| 7|
# |Pumps and compressors| 7 |
# |Electrical equipment and materials| 5|
# |Equipment and machinery subtotal| 100|

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Estimcation of euipment price for points of time</strong>
#
# If a shell-and-tube heat exchanger costs 18,000 dollars in 1996, what is the cost of a shell-and-tube heat exchanger with the same capacity in 2016?
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# Marshall and Swift Equipment cost index	is used because we are considering the cost for a heat exchanger, which is a single piece of equipment.
#
# \begin{align*}
# C_{2} &=C_{1}\Big(\frac{I_{2}}{I_{1}}\Big)\\
# C_{2} & = 18000×\Big(\frac{1582}{1036}\Big)\\
# C_{2} &  ≈ 27500
# \end{align*}
#
# </p>
# </div>
# </details>

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Estimcation of plant price for points of time</strong>
#
# If a plant producing 200,000 tons of ammonia per year costs 250 million dollars to build in 2000, what would the cost of such a plant be in 2016?
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# Since we are interested in the cost for the whole plant, we can use the Chemical Engineering Plant Cost Index.
#
# \begin{align*}
# C_{2} &=C_{1}\Big(\frac{I_{2}}{I_{1}}\Big)\\
# C_{2} & = 250,000,000×\Big(\frac{542}{394}\Big)\\
# C_{2} & ≈ 344,000,000
# \end{align*}
#
# </p>
# </div>
# </details>

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Combining effect of time and capacity for equipment cost</strong>
#
# If a 150kW Reciprocating compressor with motor drive costs 80,000 dollars in 2004, how much does the same type compressor with 500kW compacity cost in 2016?
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# We use Marshall and Swift Equipment cost index to solve for effect of time and cost exponent to solve for the effect of capacity. Both factors are multiplied so the order does not matter.
#
# \begin{align*}
# C_{2} &=C_{1}×\Big(\frac{A_{a}}{A_{b}}\Big)^n×\Big(\frac{I_{2}}{I_{1}}\Big)\\
# C_{2} & = 80000×\Big(\frac{500}{150}\Big)^{0.84}×\Big(\frac{1582}{1133}\Big)\\
# C_{2} & ≈ 307,000
# \end{align*}
#
# </p>
# </div>
# </details>

# %% [markdown]
# ## Lang factor
#
# Lang factor relates purchased equipment cost to total capital investment (TCI) and fixed capital investment(FCI). This factor represents the cost of building a major expansion onto an existing chemical plant, including other costs such as piping, control, etc.
#
# <font color="red"> $$C_{TM}=F_{lang}\sum_{i=1}^nC_{p,i}$$</font>
#
# where
# >$C_{TM}$ - total plant cost
# >
# > $F_{lang}$ - lang factor
# >
# > $\sum_{i=1}^nC_{p,i}$ - sum of the cost of all purchased equipment
#
# Lang factors for common plant types below. Note that fluid processing means plants processing liquid and/or gasses.
#
# <p style="text-align:center;"><strong>Table 6: Lang Factors for Common Plant Types $^{[1]}$</strong></p>
#
# | type of plant | FCI | TCI |
# | :-- | :--: | :--: |
# | solid processing plant | 3.9 | 4.6 |
# | solid-fluid processing plant | 4.1 | 4.9 |
# | fluid processing plant | 4.8 | 5.7 |

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Estimating FCI using the lang factor</strong>
#
# Suppose we want to build a sulfuric acid production plant. The reaction mechanism we follow are as follow:
#
# $$S_{(s)} + O_{2(g)} → SO_{2(g)}$$
# $$SO_{2(g)} + \frac{1}{2}O_{2(g)} ⇌ SO_{3(g)}$$  $$SO_{3(g)} + H_{2}SO_{4(l)} → H_{2}S_{2}O_{7(l)}$$
# $$H_{2}S_{2}O_{7(l)} +H_{2}O_{(l)} → 2H_{2}SO_{4(l)}$$
#
# The purchased price for all equipments are shown below:
#
# |Equipment categories| Puchased price |
# | :-- | :-- |
# | pre-treatment   | 3,000,000 |
# | reactors   | 8,000,000 |
# |absorption tower (for separation) | 5,000,000|
# | tanks | 2,000,000 |
# | pumps and compressors | 4,000,000  |
# | sensor and control devices | 2,000,000 |
#
# Estimate the total capital investment for the plant.
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# From the reaction mechanisms, we can find all solid, liquid and gasous phases in the process streams, so we select the lang factor to calculate TCI for solid-fluid processing plant  ($F_{lang}=4.9$).
#
#
# \begin{align*}
# TCI &=F_{lang}\sum_{i=1}^nC_{p,i}\\
# TCI &=4.9×(3,000,000+8,000,000+5,000,000+2,000,000+4,000,000+2,000,000)\\
# TCI & = 117,600,000
# \end{align*}
#
# </p>
# </div>
# </details>

# %% [markdown]
# ## Return on Investment (ROI)
#
# Return on investment is the ratio of the net profit and total capital investment ($TCI$). The net profit can be calculated by the total revenue minus cost of manufacturing($COM$). It provides a measure of how favorable the investment is.
#
# Typically $ROI$ ranges from 10%-20%. An $ROI$ over 30% for a plant is considered very desirable.
#
# <font color="red">$$ROI=\frac{(revenue-COM)}{TCI}×100\text{%}$$ </font>
#
#
# Revenue is the total profit we generated from selling the product without deducting the cost of production:
#
# <font color="red">$$\text{revenue}=\text{unit price of product} × \text{sales} $$</font>
#
# $COM$ is the total cost of operating the plant, including raw materials, utilities, labours, etc. We are going to learn about how to estimate $COM$ in the next lecture.

# %% [markdown]
# <div style="background-color:rgba(215,192, 75, 0.15)">
# <br/>
#
# <strong> Example: Estimating ROI </strong>
#
# Suppose we want to build a solid-fluid processing plant that produces soda ash ($NaCO_{3}$), and it also produces $HCl$ and $(NH)_{2}SO_{4}$ as profitable by-products. The annual production rates and market prices for our products are shown below:
#
# | product | production rate (tonne/year) | price per tonne |
# | :-- | :--: | :--: |
# | $$NaCO_{3}$$ | 120,000 | 220 |
# | $$HCl$$| 95,000 | 145 |
# | $$(NH_{4})_{2}SO_{4}$$ | 90,000 | 150 |
#
# Suppose the cost for the total purchased equipment is 18,000,000 dollars and the annual cost of manufacturing is 60,000,000 (which includes the cost of raw materials). Assuming all the products are sold, what is the return on investment for our plant? Is it feasible?
#
# </div>

# %% [markdown]
# <details>
# <summary><font color='blue'>Click here to see the solution!</font></summary>
# <div style="background-color:rgba(0, 0, 0, 0.05)">
# <p style>
#
# **Solution**
# <br/>
#
# **Step 1:** Calculate the total revenue generated by all types of products:
#
# \begin{align*}
# \text{revenue} &=\sum_{i} \text{unit price of product } i × \text{sales}\\
# &=120,000×220+95,000×145+90,000×150\\
# & = 53,675,000
# \end{align*}
#
# **Step 2:** Estimate $TCI$ using the lang factor:
#
# We select the lang factor to calculate TCI for solid-fluid processing plant ( $F_{lang}=4.9$ ) as stated in the question.
#
# $$TCI=4.9×18,000,000=88,200,000$$
#
# **Step 3:** Calculate $ROI$ using the values we calculated in the previous steps:
#
# \begin{align*}
# ROI &=\frac{(revenue-COM)}{TCI}×100\text{%}\\
# &=\frac{(53,675,000-60,000,000)}{88,200,000}×100\text{%}\\
# & = -7.17 \text{%}
# \end{align*}
#
# The project is not feasible because the return on investment is negative, which means we are in deficient even if we assume we sold all of the products.
# </p>
# </div>
# </details>

# %% [markdown]
# ### Reference
#
# [1] Data from: Analysis, Synthesis and Design of Chemical Processes, fifth edition" by Whiting, Shaeiwitz, Turton, Bhattacharyya and Bailie, originally from table 9-50, Chemical Engineers’ Handbook, Perry, Green and Maloney, 7th ed.
#
# [2] Data adapted from: Data and Techniques for Preliminary Capital Cost Estimating.
#
# [3] Chemical Engineering Magazine: http://tinyurl.com/ybaf56kt
#
# [4] G. P. Towler and R. K. Sinnott, Chemical Engineering Design: Principles, Practice, and Economics of Plant and Process Design. (2nd ed.) Waltham, MA; Oxford;: Butterworth-Heinemann, 2013; Accessible online at: http://tinyurl.com/y9oubo7n
#
# TODO:
#
# Finding Marshall and Swift index -> Go to Chemical Engineering Magazine link above from UBC Library. Use ProQuest to search the journal. Search for "economic indicators", this should bring up a variety of articles from each year with graphs and numbers for the Chemical Plant cost index and Marshall and Swift index.
